# %% [markdown]
# # splits
#
# > Leakage-aware data splits: walk-forward, purged CV, embargo.

# %%
#| default_exp splits

# %%
#| export
def walk_forward(X, n_splits: int = 5, embargo=None):
    """Walk-forward splits. Placeholder."""
    raise NotImplementedError
